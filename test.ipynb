# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py

# %%
train_dataset = h5py.File('train_catvnoncat.h5', 'r')
test_dataset = h5py.File('test_catvnoncat.h5', 'r')

# %%
train_dataset.keys()
test_dataset.keys()
# Out:
# <KeysViewHDF5 ['list_classes', 'test_set_x', 'test_set_y']>

# %%
grid = train_dataset['train_set_x']
fig = plt.figure()
print(grid)
plt.imshow(grid[0])
plt.show()
# Out:
# <HDF5 dataset "train_set_x": shape (209, 64, 64, 3), type "|u1">

# %%
plt.xkcd()
fig = plt.figure()
x = np.random.rand(10)
y = np.random.rand(10)
plt.plot(x,y)
plt.show()

# %%
fig = plt.figure()
x = np.random.rand(10)
y = np.random.rand(10)
plt.plot(x,y)
plt.show()
